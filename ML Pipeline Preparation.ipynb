# %% [markdown]
# # ML Pipeline Preparation
# This notebook is used to prepare and develop the NLP pipeline used in this project
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import nltk
nltk.download('stopwords')
nltk.download(['punkt', 'wordnet', 'averaged_perceptron_tagger'])

import pandas as pd
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sqlalchemy import create_engine 
import sqlite3
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.metrics import confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import GridSearchCV
import time
import re
from sklearn.tree import DecisionTreeClassifier
import pickle
# Out:
# [nltk_data] Downloading package stopwords to /home/ernest/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/ernest/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/ernest/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/ernest/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# load data from sqlite database
engine = create_engine('sqlite:///DisasterResponseETL4.db')

conn = engine.connect()

df = pd.read_sql_table('ETLTable', con=conn)

# Get the input parameter
X = df.iloc[:,1]

# Get the multi-output parameters Y
Y = df.iloc[:, 4:]

category_names = Y.columns

category_names
# Out:
# Index(['related', 'request', 'offer', 'aid_related', 'medical_help',
#        'medical_products', 'search_and_rescue', 'security', 'military',
#        'child_alone', 'water', 'food', 'shelter', 'clothing', 'money',
#        'missing_people', 'refugees', 'death', 'other_aid',
#        'infrastructure_related', 'transport', 'buildings', 'electricity',
#        'tools', 'hospitals', 'shops', 'aid_centers', 'other_infrastructure',
#        'weather_related', 'floods', 'storm', 'fire', 'earthquake', 'cold',
#        'other_weather', 'direct_report'],
#       dtype='object')

# %%
for i in range(20, 40):
    print(df.message[i])
# Out:
# I would like to know if one of the radio ginen Journalist died?
# I'm in Laplaine, I am a victim
# There's a lack of water in Moleya, please informed them for me.
# Those people who live at Sibert need food they are hungry.
# I want to say hello, my message is to let you know that there's an area in faustin Anhy street that has nothing neither food, water and medicine,
# Can you tell me about this service
# People I'm at Delma 2, we don't anything what so ever, please provide us with some food, water, and medicine
# We are at Gressier we needs assistance right away. ASAP, Come help us.
# How can we get water and food in Fontamara 43 cite Tinante?
# We need help. Carrefour has been forgotten completely. The foul odor is killing us. Just letting you know. Thanks!!
# Good evening, Radio one please. I would like information on Tiyous.
# We have a lot of problem at Delma 75 Avenue Albert Jode, those people need water and food.
# I'm here, I didn't find the person that I needed to send the pant by phone
# People have been sleeping outdoors in a field near Lilavois since 12 Jan. No coords on Lilavois but apparently it is near PaP
# We want you to know that Carrefour need help, we starving to death.
# How we can find food and water? we have people in many differents needs, and also for medicine at Fontamara 43 cite Tinante.
# Delmas 33 in Silo, need water.
# I would like to get help at Cote Plage in Carrefour
# I am in Leoganes, where can I get food? Please
# The Comite Miracle in the area of Alerte Rue Monseigneur Guilloux, ( Streets, Alerte and the cross street is Mgr Guilloux ) would like to urgently receive food, water and tents for the people in that area. Thanks

# %%
# Convert the Y to numpy (1-d array) array
Y = Y.values

# %% [markdown]
# ### 2. A tokenization function to process the text data

# %%
def tokenize(text):
    # Remove special characters
    text = re.sub("[^a-zA-Z0-9]", " ", text)
    words = word_tokenize(text)
    stop_words = stopwords.words('english')
    tokens = [w for w in words if w not in stop_words]
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tok = lemmatizer.lemmatize(tok, pos='v')
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline takes in the `message` column as input and output classification results on the other 36 categories in the dataset. Example sklearn MultiOutputClassifier is found in [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html)  for predicting multiple target variables.

# %%
# Define a pipeline with AdaBoostClassifier as a Classifier

pipeline1 = Pipeline([
        ('features', FeatureUnion([

            ('text_pipeline', Pipeline([
                ('count_vectorizer', CountVectorizer(tokenizer=tokenize)),
                ('tfidf_transformer', TfidfTransformer())
            ]))
            
        ])),

        ('classifier', MultiOutputClassifier(AdaBoostClassifier()))
    ])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
# %%time
X_train, X_test, y_train, y_test = train_test_split(X, Y, random_state= 0)

# train and fit the pipeline

pipeline1.fit(X_train, y_train)
# Out:
# CPU times: user 1min 16s, sys: 230 ms, total: 1min 16s
# Wall time: 1min 17s
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('text_pipeline',
#                                                  Pipeline(steps=[('count_vectorizer',
#                                                                   CountVectorizer(tokenizer=<function tokenize at 0x7f9ae40df1f0>)),
#                                                                  ('tfidf_transformer',
#                                                                   TfidfTransformer())]))])),
#                 ('classifier',
#                  MultiOutputClassifier(estimator=AdaBoostClassifier()))])

# %%
#pipeline1.get_params()

# %% [markdown]
# ### 6. Improve the model
# Grid search is used to find better parameters.

# %%
pipeline_cv1 = GridSearchCV(pipeline1, param_grid=parameters, scoring='f1_micro', n_jobs=-1)

# %%
# Train the new pipeline with Grid Search 
# %%time

pipeline_cv1.fit(X_train, y_train)

# %%
pipeline_cv1.best_params_
# Out:
# {'classifier__estimator__learning_rate': 0.01,
#  'classifier__estimator__n_estimators': 10}

# %%
# Define a pipeline with AdaBoostClassifier using the best parameters above

pipeline2 = Pipeline([
        ('features', FeatureUnion([

            ('text_pipeline', Pipeline([
                ('count_vectorizer', CountVectorizer(tokenizer=tokenize)),
                ('tfidf_transformer', TfidfTransformer())
            ]))
            
        ])),

        ('classifier', MultiOutputClassifier(AdaBoostClassifier(learning_rate = 0.01, n_estimators = 10)))
    ])

# %%
# %%time
pipeline2.fit(X_train, y_train)
# Out:
# CPU times: user 22.4 s, sys: 260 ms, total: 22.7 s
# Wall time: 22.8 s
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('text_pipeline',
#                                                  Pipeline(steps=[('count_vectorizer',
#                                                                   CountVectorizer(tokenizer=<function tokenize at 0x7f9ae40df1f0>)),
#                                                                  ('tfidf_transformer',
#                                                                   TfidfTransformer())]))])),
#                 ('classifier',
#                  MultiOutputClassifier(estimator=AdaBoostClassifier(learning_rate=0.01,
#                                                                     n_estimators=10)))])

# %%
base = [DecisionTreeClassifier(max_depth=1), DecisionTreeClassifier(max_depth=2), DecisionTreeClassifier(max_depth=8) ]

parameters2 = {
    #'classifier__estimator__algorithm': ['SAMME.R', 'SAMME'],
    'classifier__estimator__base_estimator': base
    
}

# %%
# Search for a better base_estimator
#%%timeit -n 10

start_time = time.time()
pipeline_cv2 = GridSearchCV(pipeline2, param_grid=parameters2, scoring='f1_micro', n_jobs=-1)




print(f"Time taken is {time.time() - start_time}")
# Out:
# Time taken is 0.00017452239990234375

# %% [markdown]
# # Search for a better base_estimator
# #%%timeit -n 10
#
# start_time = time.time()
#
#
#
# # Train the new pipeline with Grid Search
# pipeline_cv2.fit(X_train, y_train)
#
# print(f"Time taken is {time.time() - start_time}")

# %%
#pipeline_cv2.best_params_

# %%
# Define a pipeline with AdaBoostClassifier using the best parameters above

pipeline3 = Pipeline([
        ('features', FeatureUnion([

            ('text_pipeline', Pipeline([
                ('count_vectorizer', CountVectorizer(tokenizer=tokenize)),
                ('tfidf_transformer', TfidfTransformer())
            ]))
            
        ])),

        ('classifier', MultiOutputClassifier(AdaBoostClassifier(base_estimator = DecisionTreeClassifier(max_depth=8) , learning_rate = 0.01, n_estimators = 10)))
    ])

# %%
start_time = time.time()

pipeline3.fit(X_train, y_train)

print(f"Time take is {time.time() - start_time}")
# Out:
# Time take is 102.11413025856018

# %% [markdown]
# ### 5. Test the models
# The f1 score, precision and recall for each output category of the dataset are evaluated. This is done by iterating through the columns and calling sklearn's `classification_report`  and `accuracy_score` on each.

# %%
# Use the models to Predict the y_test values using X_test as input

#%%time
y_pred= pipeline1.predict(X_test)
#labels = y_test.columns

# %%
y_pred3 = pipeline2.predict(X_test)

# %%
y_pred4 = pipeline3.predict(X_test)

# %%
labels = ['related', 'request', 'offer', 'aid_related', 'medical_help',
       'medical_products', 'search_and_rescue', 'security', 'military',
      'child_alone', 'water', 'food', 'shelter', 'clothing', 'money',
      'missing_people', 'refugees', 'death', 'other_aid',
      'infrastructure_related', 'transport', 'buildings', 'electricity',
      'tools', 'hospitals', 'shops', 'aid_centers', 'other_infrastructure',
     'weather_related', 'floods', 'storm', 'fire', 'earthquake', 'cold',
        'other_weather', 'direct_report']

# %%
print(classification_report(y_test, y_pred4, target_names=labels))
# Out:
#                         precision    recall  f1-score   support
#
#                related       0.79      0.97      0.87      5045
#                request       0.77      0.45      0.57      1135
#                  offer       0.00      0.00      0.00        23
#            aid_related       0.68      0.56      0.62      2742
#           medical_help       0.61      0.20      0.30       524
#       medical_products       0.65      0.28      0.39       327
#      search_and_rescue       0.46      0.17      0.25       190
#               security       0.26      0.10      0.15       109
#               military       0.61      0.26      0.36       199
#            child_alone       0.00      0.00      0.00         0
#                  water       0.77      0.59      0.67       424
#                   food       0.81      0.76      0.78       727
#                shelter       0.73      0.54      0.62       588
#               clothing       0.57      0.36      0.44       109
#                  money       0.52      0.36      0.42       136
#         missing_people       0.62      0.19      0.29        81
#               refugees       0.53      0.26      0.35       213
#                  death       0.78      0.58      0.66       302
#              other_aid       0.45      0.15      0.22       867
# infrastructure_related       0.38      0.12      0.18       457
#              transport       0.63      0.26      0.37       313
#              buildings       0.65      0.38      0.48       322
#            electricity       0.50      0.32      0.39       138
#                  tools       0.29      0.11      0.16        47
#              hospitals       0.40      0.15      0.22        80
#                  shops       0.00      0.00      0.00        32
#            aid_centers       0.27      0.14      0.19        77
#   other_infrastructure       0.28      0.10      0.14       319
#        weather_related       0.90      0.56      0.69      1866
#                 floods       0.85      0.59      0.70       557
#                  storm       0.78      0.55      0.64       667
#                   fire       0.47      0.31      0.37        65
#             earthquake       0.89      0.79      0.83       592
#                   cold       0.59      0.40      0.48       123
#          other_weather       0.52      0.18      0.27       364
#          direct_report       0.69      0.32      0.43      1291
#
#              micro avg       0.75      0.57      0.64     21051
#              macro avg       0.55      0.33      0.40     21051
#           weighted avg       0.71      0.57      0.61     21051
#            samples avg       0.66      0.51      0.53     21051
# /home/ernest/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ernest/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ernest/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/ernest/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(accuracy_score(y_test, y_pred4))
# Out:
# 0.20216661580714068

# %%
for ix, label in enumerate(labels):
    print(f"{label}: {'*'*50}")
    print(classification_report(y_test[:, ix], y_pred[:, ix]))
    print('Accuracy {0:.2g}\n\n'.format(accuracy_score(y_test[:, ix], y_pred[:, ix])))
# Out:
# related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.62      0.20      0.31      1509
#           1       0.80      0.96      0.87      5045
#
# avg / total       0.76      0.79      0.74      6554
#
# Accuracy 0.79
#
#
# request: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.91      0.97      0.93      5419
#           1       0.76      0.52      0.61      1135
#
# avg / total       0.88      0.89      0.88      6554
#
# Accuracy 0.89
#
#
# offer: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6531
#           1       0.00      0.00      0.00        23
#
# avg / total       0.99      1.00      0.99      6554
#
# Accuracy 1
#
#
# aid_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.75      0.87      0.81      3812
#           1       0.77      0.60      0.68      2742
#
# avg / total       0.76      0.76      0.75      6554
#
# Accuracy 0.76
#
#
# medical_help: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      6030
#           1       0.62      0.24      0.34       524
#
# avg / total       0.91      0.93      0.91      6554
#
# Accuracy 0.93
#
#
# medical_products: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6227
#           1       0.69      0.28      0.40       327
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy 0.96
#
#
# search_and_rescue: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6364
#           1       0.62      0.16      0.25       190
#
# avg / total       0.97      0.97      0.96      6554
#
# Accuracy 0.97
#
#
# security: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6445
#           1       0.45      0.05      0.08       109
#
# avg / total       0.98      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# military: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      6355
#           1       0.64      0.35      0.45       199
#
# avg / total       0.97      0.97      0.97      6554
#
# Accuracy 0.97
#
#
# child_alone: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# Accuracy 1
#
#
# water: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.98      0.98      6130
#           1       0.74      0.69      0.71       424
#
# avg / total       0.96      0.96      0.96      6554
#
# Accuracy 0.96
#
#
# food: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97      5827
#           1       0.82      0.67      0.74       727
#
# avg / total       0.94      0.95      0.94      6554
#
# Accuracy 0.95
#
#
# shelter: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97      5966
#           1       0.75      0.54      0.62       588
#
# avg / total       0.94      0.94      0.94      6554
#
# Accuracy 0.94
#
#
# clothing: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6445
#           1       0.70      0.47      0.56       109
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# money: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      6418
#           1       0.48      0.23      0.31       136
#
# avg / total       0.97      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# missing_people: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6473
#           1       0.50      0.10      0.16        81
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# refugees: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      6341
#           1       0.56      0.26      0.35       213
#
# avg / total       0.96      0.97      0.96      6554
#
# Accuracy 0.97
#
#
# death: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      6252
#           1       0.75      0.41      0.53       302
#
# avg / total       0.96      0.97      0.96      6554
#
# Accuracy 0.97
#
#
# other_aid: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.88      0.98      0.93      5687
#           1       0.53      0.12      0.20       867
#
# avg / total       0.83      0.87      0.83      6554
#
# Accuracy 0.87
#
#
# infrastructure_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      6097
#           1       0.40      0.11      0.18       457
#
# avg / total       0.90      0.93      0.91      6554
#
# Accuracy 0.93
#
#
# transport: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6241
#           1       0.63      0.27      0.37       313
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy 0.96
#
#
# buildings: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      6232
#           1       0.60      0.39      0.47       322
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy 0.96
#
#
# electricity: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      6416
#           1       0.53      0.29      0.38       138
#
# avg / total       0.98      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# tools: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6507
#           1       0.09      0.02      0.03        47
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# hospitals: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6474
#           1       0.35      0.10      0.16        80
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# shops: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6522
#           1       0.00      0.00      0.00        32
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# aid_centers: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6477
#           1       0.31      0.14      0.19        77
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# other_infrastructure: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97      6235
#           1       0.38      0.11      0.17       319
#
# avg / total       0.93      0.95      0.93      6554
#
# Accuracy 0.95
#
#
# weather_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.88      0.96      0.92      4688
#           1       0.86      0.66      0.75      1866
#
# avg / total       0.87      0.87      0.87      6554
#
# Accuracy 0.87
#
#
# floods: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      5997
#           1       0.88      0.58      0.70       557
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy 0.96
#
#
# storm: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96      5887
#           1       0.76      0.51      0.61       667
#
# avg / total       0.93      0.93      0.93      6554
#
# Accuracy 0.93
#
#
# fire: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6489
#           1       0.53      0.15      0.24        65
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# earthquake: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      5962
#           1       0.89      0.79      0.84       592
#
# avg / total       0.97      0.97      0.97      6554
#
# Accuracy 0.97
#
#
# cold: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6431
#           1       0.62      0.37      0.46       123
#
# avg / total       0.98      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# other_weather: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      6190
#           1       0.48      0.13      0.20       364
#
# avg / total       0.92      0.94      0.93      6554
#
# Accuracy 0.94
#
#
# direct_report: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.86      0.96      0.91      5263
#           1       0.70      0.38      0.49      1291
#
# avg / total       0.83      0.85      0.83      6554
#
# Accuracy 0.85

# %%
print("GridSearch Pipeline metrics:")
for ix, label in enumerate(labels):
    print(f"{label}: {'*'*50}")
    print(classification_report(y_test[:, ix], y_pred[:, ix]))
    print('Accuracy {0:.2g}\n\n'.format(accuracy_score(y_test[:, ix], y_pred3[:, ix])))
# Out:
# GridSearch Pipeline metrics:
# related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.62      0.20      0.31      1509
#           1       0.80      0.96      0.87      5045
#
# avg / total       0.76      0.79      0.74      6554
#
# Accuracy 0.77
#
#
# request: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.91      0.97      0.93      5419
#           1       0.76      0.52      0.61      1135
#
# avg / total       0.88      0.89      0.88      6554
#
# Accuracy 0.84
#
#
# offer: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6531
#           1       0.00      0.00      0.00        23
#
# avg / total       0.99      1.00      0.99      6554
#
# Accuracy 1
#
#
# aid_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.75      0.87      0.81      3812
#           1       0.77      0.60      0.68      2742
#
# avg / total       0.76      0.76      0.75      6554
#
# Accuracy 0.64
#
#
# medical_help: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      6030
#           1       0.62      0.24      0.34       524
#
# avg / total       0.91      0.93      0.91      6554
#
# Accuracy 0.92
#
#
# medical_products: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6227
#           1       0.69      0.28      0.40       327
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy 0.95
#
#
# search_and_rescue: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6364
#           1       0.62      0.16      0.25       190
#
# avg / total       0.97      0.97      0.96      6554
#
# Accuracy 0.97
#
#
# security: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6445
#           1       0.45      0.05      0.08       109
#
# avg / total       0.98      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# military: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      6355
#           1       0.64      0.35      0.45       199
#
# avg / total       0.97      0.97      0.97      6554
#
# Accuracy 0.97
#
#
# child_alone: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# Accuracy 1
#
#
# water: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.98      0.98      6130
#           1       0.74      0.69      0.71       424
#
# avg / total       0.96      0.96      0.96      6554
#
# Accuracy 0.95
#
#
# food: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97      5827
#           1       0.82      0.67      0.74       727
#
# avg / total       0.94      0.95      0.94      6554
#
# Accuracy 0.94
#
#
# shelter: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97      5966
#           1       0.75      0.54      0.62       588
#
# avg / total       0.94      0.94      0.94      6554
#
# Accuracy 0.93
#
#
# clothing: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6445
#           1       0.70      0.47      0.56       109
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# money: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      6418
#           1       0.48      0.23      0.31       136
#
# avg / total       0.97      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# missing_people: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6473
#           1       0.50      0.10      0.16        81
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# refugees: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      6341
#           1       0.56      0.26      0.35       213
#
# avg / total       0.96      0.97      0.96      6554
#
# Accuracy 0.97
#
#
# death: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      6252
#           1       0.75      0.41      0.53       302
#
# avg / total       0.96      0.97      0.96      6554
#
# Accuracy 0.96
#
#
# other_aid: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.88      0.98      0.93      5687
#           1       0.53      0.12      0.20       867
#
# avg / total       0.83      0.87      0.83      6554
#
# Accuracy 0.87
#
#
# infrastructure_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      6097
#           1       0.40      0.11      0.18       457
#
# avg / total       0.90      0.93      0.91      6554
#
# Accuracy 0.93
#
#
# transport: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6241
#           1       0.63      0.27      0.37       313
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy 0.96
#
#
# buildings: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      6232
#           1       0.60      0.39      0.47       322
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy 0.95
#
#
# electricity: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      6416
#           1       0.53      0.29      0.38       138
#
# avg / total       0.98      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# tools: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6507
#           1       0.09      0.02      0.03        47
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# hospitals: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6474
#           1       0.35      0.10      0.16        80
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# shops: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6522
#           1       0.00      0.00      0.00        32
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 1
#
#
# aid_centers: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6477
#           1       0.31      0.14      0.19        77
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# other_infrastructure: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97      6235
#           1       0.38      0.11      0.17       319
#
# avg / total       0.93      0.95      0.93      6554
#
# Accuracy 0.95
#
#
# weather_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.88      0.96      0.92      4688
#           1       0.86      0.66      0.75      1866
#
# avg / total       0.87      0.87      0.87      6554
#
# Accuracy 0.77
#
#
# floods: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      5997
#           1       0.88      0.58      0.70       557
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy 0.96
#
#
# storm: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96      5887
#           1       0.76      0.51      0.61       667
#
# avg / total       0.93      0.93      0.93      6554
#
# Accuracy 0.92
#
#
# fire: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6489
#           1       0.53      0.15      0.24        65
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# earthquake: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      5962
#           1       0.89      0.79      0.84       592
#
# avg / total       0.97      0.97      0.97      6554
#
# Accuracy 0.96
#
#
# cold: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6431
#           1       0.62      0.37      0.46       123
#
# avg / total       0.98      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# other_weather: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      6190
#           1       0.48      0.13      0.20       364
#
# avg / total       0.92      0.94      0.93      6554
#
# Accuracy 0.95
#
#
# direct_report: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.86      0.96      0.91      5263
#           1       0.70      0.38      0.49      1291
#
# avg / total       0.83      0.85      0.83      6554
#
# Accuracy 0.81

# %% [markdown]
# ### 7. Test the tuned model
# Show the accuracy, precision, and recall of the tuned model.

# %%
#%%time
y_pred4 = pipeline3.predict(X_test)

# %%
for ix, label in enumerate(labels):
    print(f"{label}: {'*'*50}")
    print(classification_report(y_test[:, ix], y_pred[:, ix]))
    print('Accuracy {0:.2g}\n\n'.format(accuracy_score(y_test[:, ix], y_pred4[:, ix])))
# Out:
# related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.62      0.20      0.31      1509
#           1       0.80      0.96      0.87      5045
#
# avg / total       0.76      0.79      0.74      6554
#
# Accuracy 0.78
#
#
# request: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.91      0.97      0.93      5419
#           1       0.76      0.52      0.61      1135
#
# avg / total       0.88      0.89      0.88      6554
#
# Accuracy 0.87
#
#
# offer: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6531
#           1       0.00      0.00      0.00        23
#
# avg / total       0.99      1.00      0.99      6554
#
# Accuracy 1
#
#
# aid_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.75      0.87      0.81      3812
#           1       0.77      0.60      0.68      2742
#
# avg / total       0.76      0.76      0.75      6554
#
# Accuracy 0.68
#
#
# medical_help: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      6030
#           1       0.62      0.24      0.34       524
#
# avg / total       0.91      0.93      0.91      6554
#
# Accuracy 0.92
#
#
# medical_products: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6227
#           1       0.69      0.28      0.40       327
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy 0.96
#
#
# search_and_rescue: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6364
#           1       0.62      0.16      0.25       190
#
# avg / total       0.97      0.97      0.96      6554
#
# Accuracy 0.97
#
#
# security: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6445
#           1       0.45      0.05      0.08       109
#
# avg / total       0.98      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# military: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      6355
#           1       0.64      0.35      0.45       199
#
# avg / total       0.97      0.97      0.97      6554
#
# Accuracy 0.97
#
#
# child_alone: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# Accuracy 1
#
#
# water: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.98      0.98      6130
#           1       0.74      0.69      0.71       424
#
# avg / total       0.96      0.96      0.96      6554
#
# Accuracy 0.96
#
#
# food: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97      5827
#           1       0.82      0.67      0.74       727
#
# avg / total       0.94      0.95      0.94      6554
#
# Accuracy 0.95
#
#
# shelter: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97      5966
#           1       0.75      0.54      0.62       588
#
# avg / total       0.94      0.94      0.94      6554
#
# Accuracy 0.94
#
#
# clothing: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6445
#           1       0.70      0.47      0.56       109
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# money: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      6418
#           1       0.48      0.23      0.31       136
#
# avg / total       0.97      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# missing_people: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6473
#           1       0.50      0.10      0.16        81
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# refugees: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      6341
#           1       0.56      0.26      0.35       213
#
# avg / total       0.96      0.97      0.96      6554
#
# Accuracy 0.97
#
#
# death: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      6252
#           1       0.75      0.41      0.53       302
#
# avg / total       0.96      0.97      0.96      6554
#
# Accuracy 0.97
#
#
# other_aid: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.88      0.98      0.93      5687
#           1       0.53      0.12      0.20       867
#
# avg / total       0.83      0.87      0.83      6554
#
# Accuracy 0.87
#
#
# infrastructure_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.94      0.99      0.96      6097
#           1       0.40      0.11      0.18       457
#
# avg / total       0.90      0.93      0.91      6554
#
# Accuracy 0.93
#
#
# transport: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      6241
#           1       0.63      0.27      0.37       313
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy 0.96
#
#
# buildings: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.97      0.99      0.98      6232
#           1       0.60      0.39      0.47       322
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy 0.95
#
#
# electricity: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.99      6416
#           1       0.53      0.29      0.38       138
#
# avg / total       0.98      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# tools: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6507
#           1       0.09      0.02      0.03        47
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# hospitals: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6474
#           1       0.35      0.10      0.16        80
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# shops: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6522
#           1       0.00      0.00      0.00        32
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# aid_centers: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6477
#           1       0.31      0.14      0.19        77
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# other_infrastructure: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.97      6235
#           1       0.38      0.11      0.17       319
#
# avg / total       0.93      0.95      0.93      6554
#
# Accuracy 0.95
#
#
# weather_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.88      0.96      0.92      4688
#           1       0.86      0.66      0.75      1866
#
# avg / total       0.87      0.87      0.87      6554
#
# Accuracy 0.83
#
#
# floods: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      0.99      0.98      5997
#           1       0.88      0.58      0.70       557
#
# avg / total       0.95      0.96      0.95      6554
#
# Accuracy 0.96
#
#
# storm: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      0.98      0.96      5887
#           1       0.76      0.51      0.61       667
#
# avg / total       0.93      0.93      0.93      6554
#
# Accuracy 0.94
#
#
# fire: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6489
#           1       0.53      0.15      0.24        65
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# earthquake: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      0.99      0.98      5962
#           1       0.89      0.79      0.84       592
#
# avg / total       0.97      0.97      0.97      6554
#
# Accuracy 0.97
#
#
# cold: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6431
#           1       0.62      0.37      0.46       123
#
# avg / total       0.98      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# other_weather: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      6190
#           1       0.48      0.13      0.20       364
#
# avg / total       0.92      0.94      0.93      6554
#
# Accuracy 0.94
#
#
# direct_report: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.86      0.96      0.91      5263
#           1       0.70      0.38      0.49      1291
#
# avg / total       0.83      0.85      0.83      6554
#
# Accuracy 0.83

# %% [markdown]
# ### Compare the accuracies of the pipelines

# %%
d = 0
for ix, label in enumerate(labels):
    print(f"{label}: {'*'*50}")
    #print(classification_report(y_test[:, ix], y_pred[:, ix]))
    a = accuracy_score(y_test[:, ix], y_pred4[:, ix])
    b = accuracy_score(y_test[:, ix], y_pred[:, ix])
    c = a -b 
   
    if c >= 0:
          d +=1
    print('Difference in accuracy {0:.2g}\n\n'.format(c))
print("The number of positive improvement is {}".format(d))
# Out:
# related: **************************************************
# Difference in accuracy -0.012
#
#
# request: **************************************************
# Difference in accuracy -0.021
#
#
# offer: **************************************************
# Difference in accuracy 0.0012
#
#
# aid_related: **************************************************
# Difference in accuracy -0.074
#
#
# medical_help: **************************************************
# Difference in accuracy -0.0026
#
#
# medical_products: **************************************************
# Difference in accuracy -0.0023
#
#
# search_and_rescue: **************************************************
# Difference in accuracy -0.00031
#
#
# security: **************************************************
# Difference in accuracy -0.00015
#
#
# military: **************************************************
# Difference in accuracy -0.0046
#
#
# child_alone: **************************************************
# Difference in accuracy 0
#
#
# water: **************************************************
# Difference in accuracy -0.0031
#
#
# food: **************************************************
# Difference in accuracy 0.007
#
#
# shelter: **************************************************
# Difference in accuracy 0.0014
#
#
# clothing: **************************************************
# Difference in accuracy 0.00076
#
#
# money: **************************************************
# Difference in accuracy 0.0014
#
#
# missing_people: **************************************************
# Difference in accuracy 0.0014
#
#
# refugees: **************************************************
# Difference in accuracy 0.004
#
#
# death: **************************************************
# Difference in accuracy 0.0014
#
#
# other_aid: **************************************************
# Difference in accuracy -0.0012
#
#
# infrastructure_related: **************************************************
# Difference in accuracy 0.0043
#
#
# transport: **************************************************
# Difference in accuracy 0.00015
#
#
# buildings: **************************************************
# Difference in accuracy -0.0023
#
#
# electricity: **************************************************
# Difference in accuracy 0.0014
#
#
# tools: **************************************************
# Difference in accuracy 0.00031
#
#
# hospitals: **************************************************
# Difference in accuracy 0.0012
#
#
# shops: **************************************************
# Difference in accuracy 0.00092
#
#
# aid_centers: **************************************************
# Difference in accuracy 0.0017
#
#
# other_infrastructure: **************************************************
# Difference in accuracy 0.0027
#
#
# weather_related: **************************************************
# Difference in accuracy -0.048
#
#
# floods: **************************************************
# Difference in accuracy 0.00046
#
#
# storm: **************************************************
# Difference in accuracy 0.0044
#
#
# fire: **************************************************
# Difference in accuracy 0.00061
#
#
# earthquake: **************************************************
# Difference in accuracy -0.0017
#
#
# cold: **************************************************
# Difference in accuracy -0.0011
#
#
# other_weather: **************************************************
# Difference in accuracy -0.00015
#
#
# direct_report: **************************************************
# Difference in accuracy -0.015
#
#
# The number of positive improvement is 20

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
class WordCountEstimator(BaseEstimator, TransformerMixin):
    """Determine the number of words in a message."""

    def find_total_words(self, text):
        
        # Split the text into list of words
        words = word_tokenize(text)

        # Remove stop words, as thye are non-informative in our case
        stop_words = stopwords.words('english')
        tokens = [word for word in words if word not in stop_words]
        # Get and return an array of length of words and token
        obs = np.array([len(words), len(tokens)])
        return obs

    def fit(self, X, y = None):
        return self

    def transform(self, X):
        res = np.array(list(map(self.find_total_words, X)))
        res = pd.DataFrame(res)
        res.columns = ['num_words', 'num_non_stops']
        return res

# %%
improvedPipeline1 = Pipeline([
    ('features', FeatureUnion([
        ('text_pipeline', Pipeline([
            ('vect', CountVectorizer(tokenizer=tokenize))
            , ('tfidf', TfidfTransformer())]))
        , ('word_count', WordCountEstimator())]))
    , ('classifier', MultiOutputClassifier(AdaBoostClassifier(base_estimator = DecisionTreeClassifier(max_depth=3) , learning_rate = 0.01, n_estimators = 10)))])


#improvedPipeline.get_params()

# %%
improvedPipeline = Pipeline([
    ('features', FeatureUnion([
        ('text_pipeline', Pipeline([
            ('vect', CountVectorizer(tokenizer=tokenize))
            , ('tfidf', TfidfTransformer())]))
        , ('word_count', WordCountEstimator())]))
    , ('clf', RandomForestClassifier())])


#improvedPipeline.get_params()

# %%
start_time = time.time()

improvedPipeline.fit(X_train, y_train)

print(f"Time take is {time.time() - start_time}")
# Out:
# Time take is 39.867016315460205

# %%
start_time = time.time()

improvedPipeline1.fit(X_train, y_train)

print(f"Time take is {time.time() - start_time}")
# Out:
# Time take is 72.42438912391663

# %% [markdown]
# #y_train = y_train.values

# %%
# %%time
y_pred_improved = improvedPipeline.predict(X_test)
# Out:
# CPU times: user 8.08 s, sys: 200 ms, total: 8.28 s
# Wall time: 8.31 s

# %%
# %%time

y_pred_improved1 = improvedPipeline1.predict(X_test)
# Out:
# CPU times: user 8.3 s, sys: 172 ms, total: 8.47 s
# Wall time: 8.5 s

# %%
print("Improved Pipeline metrics")
for ix, label in enumerate(labels):
    print(f"{label}: {'*'*50}")
    print(classification_report(y_test[:, ix], y_pred_improved[:, ix]))
    print('Accuracy {0:.2g}\n\n'.format(accuracy_score(y_test[:, ix], y_pred_improved[:, ix])))
# Out:
# Improved Pipeline metrics
# related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.58      0.51      0.55      1509
#           1       0.86      0.89      0.87      5045
#
# avg / total       0.80      0.80      0.80      6554
#
# Accuracy 0.8
#
#
# request: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.93      5419
#           1       0.81      0.41      0.54      1135
#
# avg / total       0.87      0.88      0.86      6554
#
# Accuracy 0.88
#
#
# offer: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6531
#           1       0.00      0.00      0.00        23
#
# avg / total       0.99      1.00      0.99      6554
#
# Accuracy 1
#
#
# aid_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.71      0.90      0.79      3812
#           1       0.78      0.48      0.59      2742
#
# avg / total       0.74      0.72      0.71      6554
#
# Accuracy 0.72
#
#
# medical_help: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      6030
#           1       0.71      0.04      0.07       524
#
# avg / total       0.91      0.92      0.89      6554
#
# Accuracy 0.92
#
#
# medical_products: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6227
#           1       0.70      0.04      0.08       327
#
# avg / total       0.94      0.95      0.93      6554
#
# Accuracy 0.95
#
#
# search_and_rescue: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6364
#           1       0.33      0.01      0.01       190
#
# avg / total       0.95      0.97      0.96      6554
#
# Accuracy 0.97
#
#
# security: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6445
#           1       0.00      0.00      0.00       109
#
# avg / total       0.97      0.98      0.98      6554
#
# Accuracy 0.98
#
#
# military: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6355
#           1       0.70      0.07      0.13       199
#
# avg / total       0.96      0.97      0.96      6554
#
# Accuracy 0.97
#
#
# child_alone: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# Accuracy 1
#
#
# water: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6130
#           1       0.88      0.21      0.34       424
#
# avg / total       0.94      0.95      0.93      6554
#
# Accuracy 0.95
#
#
# food: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      5827
#           1       0.83      0.40      0.54       727
#
# avg / total       0.92      0.92      0.91      6554
#
# Accuracy 0.92
#
#
# shelter: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      5966
#           1       0.79      0.24      0.37       588
#
# avg / total       0.92      0.93      0.91      6554
#
# Accuracy 0.93
#
#
# clothing: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6445
#           1       0.88      0.14      0.24       109
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# money: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6418
#           1       1.00      0.02      0.04       136
#
# avg / total       0.98      0.98      0.97      6554
#
# Accuracy 0.98
#
#
# missing_people: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6473
#           1       1.00      0.01      0.02        81
#
# avg / total       0.99      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# refugees: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6341
#           1       0.60      0.04      0.08       213
#
# avg / total       0.96      0.97      0.95      6554
#
# Accuracy 0.97
#
#
# death: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6252
#           1       0.91      0.07      0.13       302
#
# avg / total       0.95      0.96      0.94      6554
#
# Accuracy 0.96
#
#
# other_aid: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.87      1.00      0.93      5687
#           1       0.63      0.05      0.10       867
#
# avg / total       0.84      0.87      0.82      6554
#
# Accuracy 0.87
#
#
# infrastructure_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      6097
#           1       0.12      0.00      0.00       457
#
# avg / total       0.87      0.93      0.90      6554
#
# Accuracy 0.93
#
#
# transport: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6241
#           1       0.40      0.01      0.01       313
#
# avg / total       0.93      0.95      0.93      6554
#
# Accuracy 0.95
#
#
# buildings: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6232
#           1       0.76      0.08      0.14       322
#
# avg / total       0.94      0.95      0.94      6554
#
# Accuracy 0.95
#
#
# electricity: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6416
#           1       0.67      0.01      0.03       138
#
# avg / total       0.97      0.98      0.97      6554
#
# Accuracy 0.98
#
#
# tools: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6507
#           1       0.00      0.00      0.00        47
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# hospitals: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6474
#           1       0.00      0.00      0.00        80
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# shops: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6522
#           1       0.00      0.00      0.00        32
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# aid_centers: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6477
#           1       0.00      0.00      0.00        77
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 0.99
#
#
# other_infrastructure: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6235
#           1       0.25      0.00      0.01       319
#
# avg / total       0.92      0.95      0.93      6554
#
# Accuracy 0.95
#
#
# weather_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.83      0.97      0.89      4688
#           1       0.86      0.49      0.63      1866
#
# avg / total       0.84      0.83      0.82      6554
#
# Accuracy 0.83
#
#
# floods: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      5997
#           1       0.91      0.24      0.38       557
#
# avg / total       0.93      0.93      0.92      6554
#
# Accuracy 0.93
#
#
# storm: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.92      0.99      0.96      5887
#           1       0.77      0.27      0.40       667
#
# avg / total       0.91      0.92      0.90      6554
#
# Accuracy 0.92
#
#
# fire: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6489
#           1       1.00      0.02      0.03        65
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 0.99
#
#
# earthquake: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      5962
#           1       0.88      0.46      0.60       592
#
# avg / total       0.94      0.95      0.94      6554
#
# Accuracy 0.95
#
#
# cold: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6431
#           1       0.00      0.00      0.00       123
#
# avg / total       0.96      0.98      0.97      6554
#
# Accuracy 0.98
#
#
# other_weather: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6190
#           1       0.40      0.01      0.01       364
#
# avg / total       0.91      0.94      0.92      6554
#
# Accuracy 0.94
#
#
# direct_report: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.85      0.97      0.91      5263
#           1       0.73      0.32      0.45      1291
#
# avg / total       0.83      0.84      0.82      6554
#
# Accuracy 0.84
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
print("Improved Pipeline metrics")
for ix, label in enumerate(labels):
    print(f"{label}: {'*'*50}")
    print(classification_report(y_test[:, ix], y_pred_improved1[:, ix]))
    print('Accuracy {0:.0%} \n\n'.format(accuracy_score(y_test[:, ix], y_pred_improved1[:, ix])))
# Out:
# Improved Pipeline metrics
# related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.58      0.51      0.55      1509
#           1       0.86      0.89      0.87      5045
#
# avg / total       0.80      0.80      0.80      6554
#
# Accuracy 77%
#
#
# request: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.89      0.98      0.93      5419
#           1       0.81      0.41      0.54      1135
#
# avg / total       0.87      0.88      0.86      6554
#
# Accuracy 87%
#
#
# offer: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6531
#           1       0.00      0.00      0.00        23
#
# avg / total       0.99      1.00      0.99      6554
#
# Accuracy 100%
#
#
# aid_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.71      0.90      0.79      3812
#           1       0.78      0.48      0.59      2742
#
# avg / total       0.74      0.72      0.71      6554
#
# Accuracy 67%
#
#
# medical_help: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.92      1.00      0.96      6030
#           1       0.71      0.04      0.07       524
#
# avg / total       0.91      0.92      0.89      6554
#
# Accuracy 92%
#
#
# medical_products: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6227
#           1       0.70      0.04      0.08       327
#
# avg / total       0.94      0.95      0.93      6554
#
# Accuracy 96%
#
#
# search_and_rescue: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6364
#           1       0.33      0.01      0.01       190
#
# avg / total       0.95      0.97      0.96      6554
#
# Accuracy 97%
#
#
# security: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6445
#           1       0.00      0.00      0.00       109
#
# avg / total       0.97      0.98      0.98      6554
#
# Accuracy 98%
#
#
# military: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.99      6355
#           1       0.70      0.07      0.13       199
#
# avg / total       0.96      0.97      0.96      6554
#
# Accuracy 97%
#
#
# child_alone: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6554
#
# avg / total       1.00      1.00      1.00      6554
#
# Accuracy 100%
#
#
# water: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6130
#           1       0.88      0.21      0.34       424
#
# avg / total       0.94      0.95      0.93      6554
#
# Accuracy 96%
#
#
# food: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      5827
#           1       0.83      0.40      0.54       727
#
# avg / total       0.92      0.92      0.91      6554
#
# Accuracy 95%
#
#
# shelter: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.93      0.99      0.96      5966
#           1       0.79      0.24      0.37       588
#
# avg / total       0.92      0.93      0.91      6554
#
# Accuracy 94%
#
#
# clothing: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6445
#           1       0.88      0.14      0.24       109
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 99%
#
#
# money: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6418
#           1       1.00      0.02      0.04       136
#
# avg / total       0.98      0.98      0.97      6554
#
# Accuracy 98%
#
#
# missing_people: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6473
#           1       1.00      0.01      0.02        81
#
# avg / total       0.99      0.99      0.98      6554
#
# Accuracy 99%
#
#
# refugees: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.97      1.00      0.98      6341
#           1       0.60      0.04      0.08       213
#
# avg / total       0.96      0.97      0.95      6554
#
# Accuracy 97%
#
#
# death: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.96      1.00      0.98      6252
#           1       0.91      0.07      0.13       302
#
# avg / total       0.95      0.96      0.94      6554
#
# Accuracy 97%
#
#
# other_aid: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.87      1.00      0.93      5687
#           1       0.63      0.05      0.10       867
#
# avg / total       0.84      0.87      0.82      6554
#
# Accuracy 87%
#
#
# infrastructure_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      6097
#           1       0.12      0.00      0.00       457
#
# avg / total       0.87      0.93      0.90      6554
#
# Accuracy 93%
#
#
# transport: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6241
#           1       0.40      0.01      0.01       313
#
# avg / total       0.93      0.95      0.93      6554
#
# Accuracy 96%
#
#
# buildings: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.98      6232
#           1       0.76      0.08      0.14       322
#
# avg / total       0.94      0.95      0.94      6554
#
# Accuracy 95%
#
#
# electricity: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6416
#           1       0.67      0.01      0.03       138
#
# avg / total       0.97      0.98      0.97      6554
#
# Accuracy 98%
#
#
# tools: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6507
#           1       0.00      0.00      0.00        47
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 99%
#
#
# hospitals: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6474
#           1       0.00      0.00      0.00        80
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 99%
#
#
# shops: **************************************************
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00      6522
#           1       0.00      0.00      0.00        32
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 99%
#
#
# aid_centers: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      0.99      6477
#           1       0.00      0.00      0.00        77
#
# avg / total       0.98      0.99      0.98      6554
#
# Accuracy 99%
#
#
# other_infrastructure: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      1.00      0.97      6235
#           1       0.25      0.00      0.01       319
#
# avg / total       0.92      0.95      0.93      6554
#
# Accuracy 95%
#
#
# weather_related: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.83      0.97      0.89      4688
#           1       0.86      0.49      0.63      1866
#
# avg / total       0.84      0.83      0.82      6554
#
# Accuracy 83%
#
#
# floods: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.93      1.00      0.96      5997
#           1       0.91      0.24      0.38       557
#
# avg / total       0.93      0.93      0.92      6554
#
# Accuracy 96%
#
#
# storm: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.92      0.99      0.96      5887
#           1       0.77      0.27      0.40       667
#
# avg / total       0.91      0.92      0.90      6554
#
# Accuracy 94%
#
#
# fire: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.99      1.00      1.00      6489
#           1       1.00      0.02      0.03        65
#
# avg / total       0.99      0.99      0.99      6554
#
# Accuracy 99%
#
#
# earthquake: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.95      0.99      0.97      5962
#           1       0.88      0.46      0.60       592
#
# avg / total       0.94      0.95      0.94      6554
#
# Accuracy 97%
#
#
# cold: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.98      1.00      0.99      6431
#           1       0.00      0.00      0.00       123
#
# avg / total       0.96      0.98      0.97      6554
#
# Accuracy 98%
#
#
# other_weather: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.94      1.00      0.97      6190
#           1       0.40      0.01      0.01       364
#
# avg / total       0.91      0.94      0.92      6554
#
# Accuracy 94%
#
#
# direct_report: **************************************************
#              precision    recall  f1-score   support
#
#           0       0.85      0.97      0.91      5263
#           1       0.73      0.32      0.45      1291
#
# avg / total       0.83      0.84      0.82      6554
#
# Accuracy 83%
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
d = 0
for ix, label in enumerate(labels):
    print(f"{label}: {'*'*50}")
    #print(classification_report(y_test[:, ix], y_pred[:, ix]))
    a = accuracy_score(y_test[:, ix], y_pred_improved1[:, ix])
    b = accuracy_score(y_test[:, ix], y_pred[:, ix])
    c = a -b 
   
    if c >= 0:
          d +=1
    print('Difference in accuracy {0:.2g}\n\n'.format(c))
print("The number of positive improvement is {}".format(d))
# Out:
# related: **************************************************
# Difference in accuracy -0.016
#
#
# request: **************************************************
# Difference in accuracy -0.021
#
#
# offer: **************************************************
# Difference in accuracy 0.0012
#
#
# aid_related: **************************************************
# Difference in accuracy -0.09
#
#
# medical_help: **************************************************
# Difference in accuracy -0.0024
#
#
# medical_products: **************************************************
# Difference in accuracy -0.0021
#
#
# search_and_rescue: **************************************************
# Difference in accuracy -0.00046
#
#
# security: **************************************************
# Difference in accuracy -0.00015
#
#
# military: **************************************************
# Difference in accuracy -0.0044
#
#
# child_alone: **************************************************
# Difference in accuracy 0
#
#
# water: **************************************************
# Difference in accuracy -0.0031
#
#
# food: **************************************************
# Difference in accuracy 0.007
#
#
# shelter: **************************************************
# Difference in accuracy 0.0012
#
#
# clothing: **************************************************
# Difference in accuracy 0.00092
#
#
# money: **************************************************
# Difference in accuracy 0.0014
#
#
# missing_people: **************************************************
# Difference in accuracy 0.0014
#
#
# refugees: **************************************************
# Difference in accuracy 0.004
#
#
# death: **************************************************
# Difference in accuracy 0.0014
#
#
# other_aid: **************************************************
# Difference in accuracy -0.0012
#
#
# infrastructure_related: **************************************************
# Difference in accuracy 0.0049
#
#
# transport: **************************************************
# Difference in accuracy 0.00015
#
#
# buildings: **************************************************
# Difference in accuracy -0.0023
#
#
# electricity: **************************************************
# Difference in accuracy 0.0012
#
#
# tools: **************************************************
# Difference in accuracy 0.00046
#
#
# hospitals: **************************************************
# Difference in accuracy 0.00076
#
#
# shops: **************************************************
# Difference in accuracy 0.00092
#
#
# aid_centers: **************************************************
# Difference in accuracy 0.0017
#
#
# other_infrastructure: **************************************************
# Difference in accuracy 0.0027
#
#
# weather_related: **************************************************
# Difference in accuracy -0.048
#
#
# floods: **************************************************
# Difference in accuracy 0.00046
#
#
# storm: **************************************************
# Difference in accuracy 0.0044
#
#
# fire: **************************************************
# Difference in accuracy 0.00061
#
#
# earthquake: **************************************************
# Difference in accuracy -0.0017
#
#
# cold: **************************************************
# Difference in accuracy -0.0011
#
#
# other_weather: **************************************************
# Difference in accuracy -0.00015
#
#
# direct_report: **************************************************
# Difference in accuracy -0.015
#
#
# The number of positive improvement is 20

# %% [markdown]
# ### 9. Export the model as a pickle file

# %%
pickle.dump(pipeline3, open("model.pickle", "wb"))

# %% [markdown]
# ### 10. This notebook was used to complete the `ML Pipeline in `train_classifier.py`
